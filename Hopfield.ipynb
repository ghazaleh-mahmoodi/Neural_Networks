# %% [markdown]
# #Hopfield
# Design a Hopfield Network and train it on the images of the first 10 letters of English alphabet to get
# a noisy image and correct it. In order to test model, add noise to X percent of each of the images
# and then give them to your network. In the end calculate the network’s accuracy.

# %%
# !wget https://noto-website-2.storage.googleapis.com/pkgs/NotoSans-hinted.zip
# !unzip NotoSans-hinted.zip
# !mv NotoSans-Light.ttf  /usr/share/fonts/truetype/
# !mkdir fonts
# !mv *.ttf ./fonts
# Out:
# --2020-06-14 06:20:11--  https://noto-website-2.storage.googleapis.com/pkgs/NotoSans-hinted.zip
# Resolving noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)... 108.177.111.128, 2607:f8b0:4001:c07::80
# Connecting to noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)|108.177.111.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16796031 (16M) [application/zip]
# Saving to: ‘NotoSans-hinted.zip’
#
# NotoSans-hinted.zip 100%[===================>]  16.02M  --.-KB/s    in 0.1s
#
# 2020-06-14 06:20:11 (117 MB/s) - ‘NotoSans-hinted.zip’ saved [16796031/16796031]
#
# Archive:  NotoSans-hinted.zip
#   inflating: LICENSE_OFL.txt
#   inflating: NotoSans-Black.ttf
#   inflating: NotoSans-BlackItalic.ttf
#   inflating: NotoSans-Bold.ttf
#   inflating: NotoSans-BoldItalic.ttf
#   inflating: NotoSans-Condensed.ttf
#   inflating: NotoSans-CondensedBlack.ttf
#   inflating: NotoSans-CondensedBlackItalic.ttf
#   inflating: NotoSans-CondensedBold.ttf
#   inflating: NotoSans-CondensedBoldItalic.ttf
#   inflating: NotoSans-CondensedExtraBold.ttf
#   inflating: NotoSans-CondensedExtraBoldItalic.ttf
#   inflating: NotoSans-CondensedExtraLight.ttf
#   inflating: NotoSans-CondensedExtraLightItalic.ttf
#   inflating: NotoSans-CondensedItalic.ttf
#   inflating: NotoSans-CondensedLight.ttf
#   inflating: NotoSans-CondensedLightItalic.ttf
#   inflating: NotoSans-CondensedMedium.ttf
#   inflating: NotoSans-CondensedMediumItalic.ttf
#   inflating: NotoSans-CondensedSemiBold.ttf
#   inflating: NotoSans-CondensedSemiBoldItalic.ttf
#   inflating: NotoSans-CondensedThin.ttf
#   inflating: NotoSans-CondensedThinItalic.ttf
#   inflating: NotoSans-ExtraBold.ttf
#   inflating: NotoSans-ExtraBoldItalic.ttf
#   inflating: NotoSans-ExtraCondensed.ttf
#   inflating: NotoSans-ExtraCondensedBlack.ttf
#   inflating: NotoSans-ExtraCondensedBlackItalic.ttf
#   inflating: NotoSans-ExtraCondensedBold.ttf
#   inflating: NotoSans-ExtraCondensedBoldItalic.ttf
#   inflating: NotoSans-ExtraCondensedExtraBold.ttf
#   inflating: NotoSans-ExtraCondensedExtraBoldItalic.ttf
#   inflating: NotoSans-ExtraCondensedExtraLight.ttf
#   inflating: NotoSans-ExtraCondensedExtraLightItalic.ttf
#   inflating: NotoSans-ExtraCondensedItalic.ttf
#   inflating: NotoSans-ExtraCondensedLight.ttf
#   inflating: NotoSans-ExtraCondensedLightItalic.ttf
#   inflating: NotoSans-ExtraCondensedMedium.ttf
#   inflating: NotoSans-ExtraCondensedMediumItalic.ttf
#   inflating: NotoSans-ExtraCondensedSemiBold.ttf
#   inflating: NotoSans-ExtraCondensedSemiBoldItalic.ttf
#   inflating: NotoSans-ExtraCondensedThin.ttf
#   inflating: NotoSans-ExtraCondensedThinItalic.ttf
#   inflating: NotoSans-ExtraLight.ttf
#   inflating: NotoSans-ExtraLightItalic.ttf
#   inflating: NotoSans-Italic.ttf
#   inflating: NotoSans-Light.ttf
#   inflating: NotoSans-LightItalic.ttf
#   inflating: NotoSans-Medium.ttf
#   inflating: NotoSans-MediumItalic.ttf
#   inflating: NotoSans-Regular.ttf
#   inflating: NotoSans-SemiBold.ttf
#   inflating: NotoSans-SemiBoldItalic.ttf
#   inflating: NotoSans-SemiCondensed.ttf
#   inflating: NotoSans-SemiCondensedBlack.ttf
#   inflating: NotoSans-SemiCondensedBlackItalic.ttf
#   inflating: NotoSans-SemiCondensedBold.ttf
#   inflating: NotoSans-SemiCondensedBoldItalic.ttf
#   inflating: NotoSans-SemiCondensedExtraBold.ttf
#   inflating: NotoSans-SemiCondensedExtraBoldItalic.ttf
#   inflating: NotoSans-SemiCondensedExtraLight.ttf
#   inflating: NotoSans-SemiCondensedExtraLightItalic.ttf
#   inflating: NotoSans-SemiCondensedItalic.ttf
#   inflating: NotoSans-SemiCondensedLight.ttf
#   inflating: NotoSans-SemiCondensedLightItalic.ttf
#   inflating: NotoSans-SemiCondensedMedium.ttf
#   inflating: NotoSans-SemiCondensedMediumItalic.ttf
#   inflating: NotoSans-SemiCondensedSemiBold.ttf
#   inflating: NotoSans-SemiCondensedSemiBoldItalic.ttf
#   inflating: NotoSans-SemiCondensedThin.ttf
#   inflating: NotoSans-SemiCondensedThinItalic.ttf
#   inflating: NotoSans-Thin.ttf
#   inflating: NotoSans-ThinItalic.ttf
#   inflating: README

# %%
import random
import re
import os
import numpy as np
import tkinter as tk  
import matplotlib.font_manager as fm

from matplotlib import pyplot as plt
from PIL import Image, ImageFont
from tkinter import ttk, font  
from scipy import misc

# %%
fontpath = '/usr/share/fonts/truetype/NotoSans-Light.ttf'
fontprop = fm.FontProperties(fname=fontpath, size= 40)

# %%
def create_train_images(font_size):
    imgs = {}
    shape = {}
    font = ImageFont.truetype(fontpath, font_size)

    for char in alphabets:
        img =  Image.Image()._new(font.getmask(char, mode='L'))
        img.save("train - " + str(font_size)+ " - "+ char + ".jpg")
        shape[char] = img.size
        imgs[char] = img 
    imgs_shape[font_size] = shape    
    return imgs

# %%
def create_test_images(font_size):
    imgs = {}

    for noise in noises:
        imgs[noise] = {}

        for char in alphabets:
            img = np.array(train_imgs[font_size][char])
            
            pixels_count = img.shape[0] * img.shape[1] 
            noisypx_count = int(noise * pixels_count)

            random_pxs = random.sample(range(0, pixels_count), noisypx_count)
            
            for i in random_pxs:
                row = int(i / img.shape[1]) 
                column = int(i % img.shape[1]) 

                img[row,column] = 255 if img[row,column] < 125  else 0 
            
            img = Image.fromarray(img, mode="L")
            imgs[noise][char] = img
            img.save("test -" + str(font_size) + " - noise - "+ str(noise)+ " - "+ char + " - "+ ".jpg")
            
           
    return imgs

# %%
def create_data():

   for fsize in font_sizes:
        train_imgs[fsize] = create_train_images(fsize)
        test_imgs[fsize] = {}
        test_imgs[fsize] = create_test_images(fsize)

# %%
# Read Image file and convert it to Numpy array
def image_to_array(image, threshold = 45):
    image =image.resize((100, 100))
    image = np.array(image)
    y= np.zeros(image.shape, dtype=np.float)
    y[image > threshold] = 1
    y[y == 0] = -1
    return y
    
# convert matrix to a vector
def matrix_to_vector(x):
    return x.flatten()


# Create Weight matrix for a single image
def create_matrix_w(x):
    w = np.zeros([len(x),len(x)])
    for i in range(len(x)):
        for j in range(i,len(x)):
            if i == j:
                w[i, j] = 0
            else:
                w[i, j] = x[i]*x[j]
                w[j, i] = w[i, j]
    return w

# Convert Numpy array to Image file like Jpeg
def array_to_img(data, font_size, char):
    y = np.zeros(data.shape, dtype=np.uint8)
    y[data == 1] = 255
    y[data == -1] = 0
    img = Image.fromarray(y, mode="L")
    # img = img.resize(imgs_shape[font_size][char])
    return img


def update(w, y_vec, theta=0.5, time=100):
    for s in range(time):
        i = random.randint(0, len(y_vec) - 1)
        u = np.dot(w[i][:], y_vec) - theta
        y_vec[i] = 1 if u > 0 else -1

    return y_vec

# %%
# Initial setting
def hopfield(font,train_files, test_files,
             theta=0.5, time=1000):
    
    # read image and convert it to Numpy array
    print("Importing images and creating weight matrix....")

    # num_files is the number of files -- Training
    w = []
    for char in alphabets:
        print (char, "   ", "font : ", font)
        x = image_to_array(train_files[char])
        x_vec = matrix_to_vector(x)
        
        if char == 'A':
            w = create_matrix_w(x_vec)
        else:
            w = w + create_matrix_w(x_vec)

    print(w)

    print("Weight matrix is done!!")

    #Import test data -- testing
    for noise in noises :
        for char in alphabets:
            y = image_to_array(test_files[noise][char])

            oshape = y.shape
            print( "test data : ", "noise = ", noise,"font :",   font )

            y_vec = matrix_to_vector(y)
            
            y_vec_after = update(w=w, y_vec=y_vec, theta=theta, time=time)
            y_vec_after = y_vec_after.reshape(oshape)
            
            newimage = array_to_img(y_vec_after, font, char)
            newimage.save("output -"+str(font ) + "- noise - "+ str(noise)+ " - "+ char + " - "+ ".jpg")

# %%
def main():
    
    create_data()
    print("data creation finished  \n")   
    

    for font in font_sizes:
        hopfield(font, train_files=train_imgs[font], test_files=test_imgs[font], 
                theta=0.5, time=20000)

# %%
Round = 0

# %%
alphabets = "ABCDEFGHIJ"
font_sizes = [16, 32, 64]
noises = [0.1, 0.3, 0.6]

train_imgs = {}  
test_imgs = {}
imgs_shape = {}

main()
# ! unzip images2.zip
! zip images{tryRound}.zip *.jpg
! rm *.jpg
Round += 1
# Out:
# data creation finished
#
# Importing images and creating weight matrix....
# A     font :  16
# B     font :  16
# C     font :  16
# D     font :  16
# E     font :  16
# F     font :  16
# G     font :  16
# H     font :  16
# I     font :  16
# J     font :  16
# [[ 0. 10. 10. ...  8.  8.  8.]
#  [10.  0. 10. ...  8.  8.  8.]
#  [10. 10.  0. ...  8.  8.  8.]
#  ...
#  [ 8.  8.  8. ...  0. 10. 10.]
#  [ 8.  8.  8. ... 10.  0. 10.]
#  [ 8.  8.  8. ... 10. 10.  0.]]
# Weight matrix is done!!
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.1 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.3 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# test data :  noise =  0.6 font : 16
# Updating...
# Importing images and creating weight matrix....
# A     font :  32
# B     font :  32
# C     font :  32
# D     font :  32
# E     font :  32
# F     font :  32
# G     font :  32
# H     font :  32
# I     font :  32
# J     font :  32
# [[ 0. 10. 10. ...  8.  8.  8.]
#  [10.  0. 10. ...  8.  8.  8.]
#  [10. 10.  0. ...  8.  8.  8.]
#  ...
#  [ 8.  8.  8. ...  0. 10. 10.]
#  [ 8.  8.  8. ... 10.  0. 10.]
#  [ 8.  8.  8. ... 10. 10.  0.]]
# Weight matrix is done!!
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.1 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.3 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# test data :  noise =  0.6 font : 32
# Updating...
# Importing images and creating weight matrix....
# A     font :  64
# B     font :  64
# C     font :  64
# D     font :  64
# E     font :  64
# F     font :  64
# G     font :  64
# H     font :  64
# I     font :  64
# J     font :  64
# [[ 0. 10. 10. ...  8.  8.  8.]
#  [10.  0. 10. ...  8.  8.  8.]
#  [10. 10.  0. ...  8.  8.  8.]
#  ...
#  [ 8.  8.  8. ...  0. 10. 10.]
#  [ 8.  8.  8. ... 10.  0. 10.]
#  [ 8.  8.  8. ... 10. 10.  0.]]
# Weight matrix is done!!
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.1 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.3 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
# test data :  noise =  0.6 font : 64
# Updating...
#   adding: output -16- noise - 0.1 - A - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - B - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - C - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - D - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - E - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - F - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - G - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - H - .jpg (deflated 1%)
#   adding: output -16- noise - 0.1 - I - .jpg (stored 0%)
#   adding: output -16- noise - 0.1 - J - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - A - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - B - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - C - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - D - .jpg (deflated 0%)
#   adding: output -16- noise - 0.3 - E - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - F - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - G - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - H - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - I - .jpg (stored 0%)
#   adding: output -16- noise - 0.3 - J - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - A - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - B - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - C - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - D - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - E - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - F - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - G - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - H - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - I - .jpg (stored 0%)
#   adding: output -16- noise - 0.6 - J - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - A - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - B - .jpg (deflated 0%)
#   adding: output -32- noise - 0.1 - C - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - D - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - E - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - F - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - G - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - H - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - I - .jpg (stored 0%)
#   adding: output -32- noise - 0.1 - J - .jpg (deflated 0%)
#   adding: output -32- noise - 0.3 - A - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - B - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - C - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - D - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - E - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - F - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - G - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - H - .jpg (deflated 0%)
#   adding: output -32- noise - 0.3 - I - .jpg (stored 0%)
#   adding: output -32- noise - 0.3 - J - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - A - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - B - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - C - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - D - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - E - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - F - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - G - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - H - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - I - .jpg (stored 0%)
#   adding: output -32- noise - 0.6 - J - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - A - .jpg (deflated 0%)
#   adding: output -64- noise - 0.1 - B - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - C - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - D - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - E - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - F - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - G - .jpg (deflated 0%)
#   adding: output -64- noise - 0.1 - H - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - I - .jpg (stored 0%)
#   adding: output -64- noise - 0.1 - J - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - A - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - B - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - C - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - D - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - E - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - F - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - G - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - H - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - I - .jpg (stored 0%)
#   adding: output -64- noise - 0.3 - J - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - A - .jpg (deflated 0%)
#   adding: output -64- noise - 0.6 - B - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - C - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - D - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - E - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - F - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - G - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - H - .jpg (deflated 0%)
#   adding: output -64- noise - 0.6 - I - .jpg (stored 0%)
#   adding: output -64- noise - 0.6 - J - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - A - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - B - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - C - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - D - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - E - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - F - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - G - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - H - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - I - .jpg (stored 0%)
#   adding: test -16 - noise - 0.1 - J - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - A - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - B - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - C - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - D - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - E - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - F - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - G - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - H - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - I - .jpg (stored 0%)
#   adding: test -16 - noise - 0.3 - J - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - A - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - B - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - C - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - D - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - E - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - F - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - G - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - H - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - I - .jpg (stored 0%)
#   adding: test -16 - noise - 0.6 - J - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - A - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - B - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - C - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - D - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - E - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - F - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - G - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - H - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - I - .jpg (stored 0%)
#   adding: test -32 - noise - 0.1 - J - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - A - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - B - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - C - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - D - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - E - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - F - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - G - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - H - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - I - .jpg (stored 0%)
#   adding: test -32 - noise - 0.3 - J - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - A - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - B - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - C - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - D - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - E - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - F - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - G - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - H - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - I - .jpg (stored 0%)
#   adding: test -32 - noise - 0.6 - J - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - A - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - B - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - C - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - D - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - E - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - F - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - G - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - H - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - I - .jpg (stored 0%)
#   adding: test -64 - noise - 0.1 - J - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - A - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - B - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - C - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - D - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - E - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - F - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - G - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - H - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - I - .jpg (stored 0%)
#   adding: test -64 - noise - 0.3 - J - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - A - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - B - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - C - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - D - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - E - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - F - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - G - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - H - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - I - .jpg (stored 0%)
#   adding: test -64 - noise - 0.6 - J - .jpg (stored 0%)
#   adding: train - 16 - A.jpg (stored 0%)
#   adding: train - 16 - B.jpg (stored 0%)
#   adding: train - 16 - C.jpg (stored 0%)
#   adding: train - 16 - D.jpg (stored 0%)
#   adding: train - 16 - E.jpg (stored 0%)
#   adding: train - 16 - F.jpg (deflated 0%)
#   adding: train - 16 - G.jpg (stored 0%)
#   adding: train - 16 - H.jpg (stored 0%)
#   adding: train - 16 - I.jpg (stored 0%)
#   adding: train - 16 - J.jpg (deflated 0%)
#   adding: train - 32 - A.jpg (stored 0%)
#   adding: train - 32 - B.jpg (stored 0%)
#   adding: train - 32 - C.jpg (stored 0%)
#   adding: train - 32 - D.jpg (stored 0%)
#   adding: train - 32 - E.jpg (stored 0%)
#   adding: train - 32 - F.jpg (stored 0%)
#   adding: train - 32 - G.jpg (stored 0%)
#   adding: train - 32 - H.jpg (stored 0%)
#   adding: train - 32 - I.jpg (stored 0%)
#   adding: train - 32 - J.jpg (stored 0%)
#   adding: train - 64 - A.jpg (stored 0%)
#   adding: train - 64 - B.jpg (stored 0%)
#   adding: train - 64 - C.jpg (stored 0%)
#   adding: train - 64 - D.jpg (deflated 5%)
#   adding: train - 64 - E.jpg (deflated 6%)
#   adding: train - 64 - F.jpg (deflated 3%)
#   adding: train - 64 - G.jpg (stored 0%)
#   adding: train - 64 - H.jpg (deflated 11%)
#   adding: train - 64 - I.jpg (stored 0%)
#   adding: train - 64 - J.jpg (stored 0%)
