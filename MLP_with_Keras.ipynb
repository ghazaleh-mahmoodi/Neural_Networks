# %% [markdown]
# #section 2
# ------------------------------------------------------

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# %%
def plot(history):
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
def model(x_train, y_train, x_test, y_test, epoch = 100):

    # Define model
    model = Sequential()
    model.add(Dense(128, input_dim=1, activation='relu'))
    model.add(Dropout(0.02))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam')
    history = model.fit(x_train, y_train, epochs=epoch, batch_size=512, verbose = 0,
                        validation_data = (x_test, y_test))

    
    plot(history)

    predictions = model.predict(x_test)
    
    plt.plot(x_test, y_test, label='Actual')
    plt.plot(x_test ,predictions, label='Predicted')
    plt.legend()
    plt.show()

# %%
def model_deeper(x_train, y_train, x_test, y_test, epoch = 100):

    # Define model
    model = Sequential()
    model.add(Dense(1024, input_dim=1, activation='relu'))
    model.add(Dropout(0.02))
    model.add(Dense(512, activation='relu'))
    model.add(Dense(1))

    model.compile(loss='mean_squared_error', optimizer='adam')
    history = model.fit(x_train, y_train, epochs=epoch, batch_size=512, verbose = 0,
                        validation_data = (x_test, y_test))

    
    plot(history)

    predictions = model.predict(x_test)
    
    plt.plot(x_test, y_test, label='Actual')
    plt.plot(x_test ,predictions, label='Predicted')
    plt.legend()
    plt.show()

# %% [markdown]
# #sin(X)
#
# --------------------------------------------------------------------

# %%
x = np.random.random((40000,1))* 100 - 10
y = np.sin(x)

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 100)

# %%
x = np.random.random((2500,1))* 100 - 10
y = np.sin(x)

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 500)

# %%
x = np.random.random((40000,1))* 100 - 20
y = np.sin(x)

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 500)

# %%
x = np.random.random((40000,1))* 100 - 20
y = np.sin(x)

x_test = np.arange(-10*np.pi, 10*np.pi, 0.01)
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 500)

# %%
x = np.random.random((40000,1))* 100 - 10
y = np.sin(x)

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test)

model_deeper(x, y, x_test, y_test, 100)

# %% [markdown]
# #X^2
#
# --------------------------------------------------

# %%
# -10 < x < 10
x = np.random.random((250,1))* 100 - 10 
y = x**2

x_test = np.arange(-25, 25, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,100)

# %%
# -10 < x < 10
x = np.random.random((2500,1))* 100 - 10 
y = x**2

x_test = np.arange(-25, 25, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %%
# -10 < x < 10
x = np.random.random((250,1))* 100 - 10 
y = x**2

x_test = np.arange(-25, 25, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test,1000)

# %%
# -10 < x < 10
x = np.random.random((25000,1))* 100 - 20 
y = x**2

x_test = np.arange(-55, 55, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test,2000)

# %% [markdown]
# #sin(x) + x
#
#
# ---------------------------------------------------------------------

# %%
x = np.random.random((40000,1))* 100 - 10
y = np.sin(x) + x

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test) + x_test

model(x, y, x_test, y_test, 100)

# %%
x = np.random.random((40000,1))* 100 - 10
y = np.sin(x) + x

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test) + x_test

model(x, y, x_test, y_test, 1000)

# %% [markdown]
# #section 3 - noisy data
#
# --------------------------------------------------------------------

# %% [markdown]
# #sin(x) --noisy

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + np.random.uniform(low=-0.1, high=0.1, size=(len(x)))

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test) 

model(x, y, x_test, y_test, 500)

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + np.random.uniform(low=-0.1, high=0.1, size=(len(x)))

x_test = np.arange(0, 2*np.pi, 0.1)
y_test = np.sin(x_test) 

model(x, y, x_test, y_test, 500)

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + np.random.uniform(low=-1, high=1, size=(len(x)))

x_test = np.arange(0, 10*np.pi, 0.1) 
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 100)

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + np.random.uniform(low=-1, high=1, size=(len(x)))

x_test = np.arange(0, 2*np.pi, 0.1) 
y_test = np.sin(x_test)

model(x, y, x_test, y_test, 100)

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + np.random.uniform(low=-0.9, high=0.9, size=(len(x)))

x_test = np.arange(0, 10*np.pi, 0.1)
y_test = np.sin(x_test) 

model(x, y, x_test, y_test, 100)

# %% [markdown]
# #X ^ 2 -- noisy
#
# -----------------------------------------------------------

# %%
# -10 < x < 10
x = np.random.random((2500,1))* 100 - 10 
y = x**2 + np.random.uniform(low=-0.5, high=0.5, size=(len(x)))

x_test = np.arange(-25, 25, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %%
# -10 < x < 10
x = np.random.random((2500,1))* 100 - 10 
y = x**2 + np.random.uniform(low=-10, high=+10, size=(len(x)))

x_test = np.arange(-5, 5, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %%
# -10 < x < 10
x = np.random.random((2500,1))* 100 - 10 
y = x**2 + np.random.uniform(low=-50, high=+50, size=(len(x)))

x_test = np.arange(-25, 25, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %%
x = np.random.random((2500,1))* 100 - 10 
y = x**2 + np.random.uniform(low=-50, high=+50, size=(len(x)))

x_test = np.arange(-5, 5, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %%
# -10 < x < 10
x = np.random.random((2500,1))* 100 - 10 
y = x**2 + np.random.uniform(low=-70, high=+80, size=(len(x)))

x_test = np.arange(-5, 5, 0.1)
y_test = x_test**2

model(x, y, x_test, y_test ,500)

# %% [markdown]
# #Sin(x) + X

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + x + np.random.uniform(low=-0.5, high=0.5, size=(len(x)))

x_test = np.arange(0, 2*np.pi, 0.1)
y_test = np.sin(x_test) + x_test

model(x, y, x_test, y_test, 100)

# %%
x = np.random.random((4000,1))* 100 - 10
y = np.sin(x) + x + np.random.uniform(low=-20, high=20, size=(len(x)))

x_test = np.arange(0, 2*np.pi, 0.1)
y_test = np.sin(x_test) + x_test

model(x, y, x_test, y_test, 1000)
